# %%
import pandas as pd
import datetime
import time

csv_path = r"U:\jupyter\insulation_amp_2026\insulation_amp_2026\output_data_insulation_amp_2026_v1.csv"

# 10분마다 CSV를 다시 읽어서 데이터 개수 출력
while True:
    df = pd.read_csv(csv_path)
    print("현재 시간:", datetime.datetime.now())
    print("row count:", len(df))
    time.sleep(60)
# Out:
# 현재 시간: 2026-01-27 18:09:37.645208
# 3442
# ...

# %%
import pandas as pd

# pandas 출력이 컬럼/문자열을 잘라서 보이지 않도록 설정
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

csv_path = r"U:\jupyter\insulation_amp_2026\insulation_amp_2026\output_data_insulation_amp_2026_v1.csv"
df = pd.read_csv(csv_path)

import datetime
print("현재 시간:", datetime.datetime.now())
print(len(df))


df = df[df["Gv_28"] < 1.55]
df = df[df["Gv_28"] > 1.45]
# df = df[df["Gv_1000"] < 1.55]
# df = df[df["Gv_1000"] > 1.45]

df = df[df["LT_10M"] > 100]

df.head()

# %%
import pandas as pd

# pandas 출력이 컬럼/문자열을 잘라서 보이지 않도록 설정
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

csv_path = r"U:\jupyter\insulation_amp_2026\insulation_amp_2026\output_data_insulation_amp_2026_v1.csv"
df = pd.read_csv(csv_path)


df["sim_time"].mean()

df
# Out:
# np.float64(610.1427494407768)
